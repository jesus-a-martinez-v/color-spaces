# %% [markdown]
# # Espacios de color
#
# En este notebook veremos brevemente cómo manipular espacios de color tanto en `OpenCV` como en `scikit-image`.

# %% [markdown]
# ## OpenCV
#
# Empecemos por cargar una imagen:

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('./crayons.jpeg', cv2.IMREAD_COLOR)
print(img.shape)

# Tenemos que convertir a espacio RGB, porque OpenCV carga las imágenes como BGR.
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)
# Out:
# (426, 640, 3)

# %%
# Mostremos cada uno de los canales de la imagen en RGB.
red_channel = rgb_image[:, :, 0]
green_channel = rgb_image[:, :, 1]
blue_channel = rgb_image[:, : , 2]

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
ax1.set_title("Rojo")
ax1.imshow(red_channel, cmap="gray")

ax2.set_title("Verde")
ax2.imshow(green_channel, cmap="gray")

ax3.set_title("Azul")
ax3.imshow(blue_channel, cmap="gray")

# %%
# Pasemos a espacio HSV

hsv_image = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2HSV)

print(hsv_image.shape)

plt.imshow(hsv_image)
# Out:
# (426, 640, 3)

# %% [markdown]
# Dado que la imagen se encuentra en espacio HSV, los colores se ven distorsionados. ¿Por qué? Pues, la función imshow asume que las imágenes vienen en formato RGB, por lo que al ser interpretadas en este espacio, obtenemos el resultado mostrado anteriormente.
#
# Veamos cómo se ve cada canal.

# %%
hue_channel = hsv_image[:, :, 0]
saturation_channel = hsv_image[:, :, 1]
value_channel = hsv_image[:, :, 2]

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
ax1.set_title("Matiz")
ax1.imshow(hue_channel, cmap="gray")

ax2.set_title("Saturación")
ax2.imshow(saturation_channel, cmap="gray")

ax3.set_title("Brillo")
ax3.imshow(value_channel, cmap="gray")

# %% [markdown]
# ## scikit-image
#
# Procedamos a repetir el proceso usando `skimage`.

# %%
from skimage import io, color

img = io.imread('./crayons.jpeg')

plt.imshow(img)

# %%
# Mostremos cada uno de los canales de la imagen en RGB.
red_channel = rgb_image[:, :, 0]
green_channel = rgb_image[:, :, 1]
blue_channel = rgb_image[:, : , 2]

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
ax1.set_title("Rojo")
ax1.imshow(red_channel, cmap="gray")

ax2.set_title("Verde")
ax2.imshow(green_channel, cmap="gray")

ax3.set_title("Azul")
ax3.imshow(blue_channel, cmap="gray")

# %%
# Pasemos a espacio HSV

hsv_image = color.rgb2hsv(rgb_image)

plt.imshow(hsv_image)

# %%
hue_channel = hsv_image[:, :, 0]
saturation_channel = hsv_image[:, :, 1]
value_channel = hsv_image[:, :, 2]

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))
ax1.set_title("Matiz")
ax1.imshow(hue_channel, cmap="gray")

ax2.set_title("Saturación")
ax2.imshow(saturation_channel, cmap="gray")

ax3.set_title("Brillo")
ax3.imshow(value_channel, cmap="gray")
